# %% [markdown]
# # Capstone: Musical Recommender

# %% [markdown]
# Kelly Slatery | US-DSI-10

# %%
# Imports
import numpy as np
import pandas as pd

import showmetunes

# Set view options
pd.set_option('display.max_columns', 10000)

# %% [markdown]
# # Create Ouput File

# %%
# Create list of first two columns to track
output_columns = ['user_input', 'recommendations']

# %%
# Import dataframe of the names of all possible musicals
names = pd.read_csv('./data/musical_names.csv')
names.head()
# Out:
#                     musical
# 0            Les Misérables
# 1  The Phantom of the Opera
# 2                  Hamilton
# 3           West Side Story
# 4                    Wicked

# %%
# Add each musical name as a column name
for i in range(len(names)):
    output_columns.append(names.values[i][0])
output_columns[:3]
# Out:
# ['user_input', 'recommendations', 'Les Misérables']

# %%
# Create the empty dataframe for tracking musical recommendations
output_df = pd.DataFrame(columns=output_columns)
output_df
# Out:
# Empty DataFrame
# Columns: [user_input, recommendations, Les Misérables, The Phantom of the Opera, Hamilton, West Side Story, Wicked, Chicago, Rent, The Lion King, The Book of Mormon, Sweeney Todd: The Demon Barber of Fleet Street, The Sound of Music, Fiddler on the Roof, Into the Woods, Dear Evan Hansen, Hairspray, A Chorus Line, Cabaret, Little Shop of Horrors, Grease, Newsies, My Fair Lady, Evita, Jesus Christ Superstar, Annie, Singin' in the Rain, The Music Man, Matilda, Spring Awakening, Avenue Q, In the Heights, Beauty and the Beast, The King and I, Mary Poppins, Joseph and the Amazing Technicolor Dreamcoat, Mamma Mia!, Cats, Guys and Dolls, Pippin, Anything Goes, Kinky Boots, Miss Saigon, oklahoma, Next to Normal, The Producers, Gypsy: A Musical Fable, Dreamgirls, Hello, Dolly!, Jersey Boys, Oliver!, Hair, Something Rotten, Waitress, Ragtime, Heathers, Cinderella, Falsettos, Peter Pan, South Pacific, Spamalot, Company, Annie Get Your Gun, Funny Girl, The Color Purple, Carousel, The Little Mermaid, Bye Bye Birdie, Billy Elliot the Musical, The addams family, School of Rock - the Musical, The Rocky Horror Show, Thoroughly Modern Millie, Legally Blonde, Godspell, How to Succeed in Business Without Really Trying, Camelot, Hedwig and the Angry Inch, Come from Away, Show Boat, 42nd Street, Man of La Mancha, Sunday in the Park with George, You're a Good Man, Charlie Brown, Follies, A Little Night Music, La Cage aux Folles, Urinetown, Sunset Boulevard, Aladdin, Anastasia, The Secret Garden, Victor/Victoria, Assassins, Porgy and Bess, Finding Neverland, Chitty Chitty Bang Bang, The 25th Annual Putnam County Spelling Bee, A Funny Thing Happened on the Way to the Forum, The Pirates of Penzance, ...]
# Index: []

# %%
# Export empty dataframe to a csv
# output_df.to_csv('./data/recommender_output.csv', index=False)

# %% [markdown]
# # Create Tracker

# %%
# Define a function to add the new input and recommendations to the above dataframe 
# each time the recommender is run and count all occurrences of musicals
def track_output(df, user_input, recommendations):
    # Initialize a new row to track this round of recommendations
    new_row = pd.DataFrame([[user_input, recommendations]], columns=['user_input', 'recommendations'])
    
    # Track how many times a musical is recommended
    df = pd.concat([df,new_row], axis=0, ignore_index=True)
    for rec in recommendations:
        for col in df.columns:
            if rec == col:
                df.loc[df['user_input'] == user_input, col] = 1
    
    # Fill nulls (musicals not recommended) with 0s
    df.fillna(0, inplace=True)   
    return df

# %% [markdown]
# # Test Tracker

# %%
# Import empty dataframe created above
tracker = pd.read_csv('./data/recommender_output.csv')
tracker
# Out:
# Empty DataFrame
# Columns: [user_input, recommendations, Les Misérables, The Phantom of the Opera, Hamilton, West Side Story, Wicked, Chicago, Rent, The Lion King, The Book of Mormon, Sweeney Todd: The Demon Barber of Fleet Street, The Sound of Music, Fiddler on the Roof, Into the Woods, Dear Evan Hansen, Hairspray, A Chorus Line, Cabaret, Little Shop of Horrors, Grease, Newsies, My Fair Lady, Evita, Jesus Christ Superstar, Annie, Singin' in the Rain, The Music Man, Matilda, Spring Awakening, Avenue Q, In the Heights, Beauty and the Beast, The King and I, Mary Poppins, Joseph and the Amazing Technicolor Dreamcoat, Mamma Mia!, Cats, Guys and Dolls, Pippin, Anything Goes, Kinky Boots, Miss Saigon, oklahoma, Next to Normal, The Producers, Gypsy: A Musical Fable, Dreamgirls, Hello, Dolly!, Jersey Boys, Oliver!, Hair, Something Rotten, Waitress, Ragtime, Heathers, Cinderella, Falsettos, Peter Pan, South Pacific, Spamalot, Company, Annie Get Your Gun, Funny Girl, The Color Purple, Carousel, The Little Mermaid, Bye Bye Birdie, Billy Elliot the Musical, The addams family, School of Rock - the Musical, The Rocky Horror Show, Thoroughly Modern Millie, Legally Blonde, Godspell, How to Succeed in Business Without Really Trying, Camelot, Hedwig and the Angry Inch, Come from Away, Show Boat, 42nd Street, Man of La Mancha, Sunday in the Park with George, You're a Good Man, Charlie Brown, Follies, A Little Night Music, La Cage aux Folles, Urinetown, Sunset Boulevard, Aladdin, Anastasia, The Secret Garden, Victor/Victoria, Assassins, Porgy and Bess, Finding Neverland, Chitty Chitty Bang Bang, The 25th Annual Putnam County Spelling Bee, A Funny Thing Happened on the Way to the Forum, The Pirates of Penzance, ...]
# Index: []

# %%
# Define an input to test
my_input = '''Today, I\'m feeling okay about things. There have been a lot of changes recently, 
                but I\'m adapting and I have my friends and music and a path to go down...
                it\'s all going to be okay!'''

# %%
# Get recommendations
recs = showmetunes.recommend(my_input)
recs
# Out:
# ['The 25th Annual Putnam County Spelling Bee', 'Baby', 'Rock of Ages']

# %%
# Add a new row to the dataframe to track these reocmmendations, but do not export!
updated_output = track_output(tracker, my_input, recs)
updated_output
# Out:
#                                           user_input  \
# 0  Today, I'm feeling okay about things. There ha...
#
#                                      recommendations  Les Misérables  \
# 0  [The 25th Annual Putnam County Spelling Bee, B...               0
#
#    The Phantom of the Opera  Hamilton  West Side Story  Wicked  Chicago  Rent  \
# 0                         0         0                0       0        0     0
#
#    The Lion King  The Book of Mormon  \
# 0              0                   0
#
#    Sweeney Todd: The Demon Barber of Fleet Street  The Sound of Music  \
# 0                                               0                   0
#
#    Fiddler on the Roof  Into the Woods  Dear Evan Hansen  Hairspray  \
# 0                    0               0                 0          0
#
#    A Chorus Line  Cabaret  Little Shop of Horrors  Grease  Newsies  \
# 0              0        0                       0       0        0
#
#    My Fair Lady  Evita  Jesus Christ Superstar  Annie  Singin' in the Rain  \
# 0             0      0                       0      0                    0
#
#    The Music Man  Matilda  Spring Awakening  Avenue Q  In the Heights  \
# 0              0        0                 0         0               0
#
#    Beauty and the Beast  The King and I  Mary Poppins  \
# 0                     0               0             0
#
#    Joseph and the Amazing Technicolor Dreamcoat  Mamma Mia!  Cats  \
# 0                                             0           0     0
#
#    Guys and Dolls  Pippin  Anything Goes  Kinky Boots  Miss Saigon  oklahoma  \
# 0               0       0              0            0            0         0
#
#    Next to Normal  The Producers  Gypsy: A Musical Fable  Dreamgirls  \
# 0               0              0                       0           0
#
#    Hello, Dolly!  Jersey Boys  Oliver!  Hair  Something Rotten  Waitress  \
# 0              0            0        0     0                 0         0
#
#    Ragtime  Heathers  Cinderella  Falsettos  Peter Pan  South Pacific  \
# 0        0         0           0          0          0              0
#
#    Spamalot  Company  Annie Get Your Gun  Funny Girl  The Color Purple  \
# 0         0        0                   0           0                 0
#
#    Carousel  The Little Mermaid  Bye Bye Birdie  Billy Elliot the Musical  \
# 0         0                   0               0                         0
#
#    The addams family  School of Rock - the Musical  The Rocky Horror Show  \
# 0                  0                             0                      0
#
#    Thoroughly Modern Millie  Legally Blonde  Godspell  \
# 0                         0               0         0
#
#    How to Succeed in Business Without Really Trying  Camelot  \
# 0                                                 0        0
#
#    Hedwig and the Angry Inch  Come from Away  Show Boat  42nd Street  \
# 0                          0               0          0            0
#
#    Man of La Mancha  Sunday in the Park with George  \
# 0                 0                               0
#
#    You're a Good Man, Charlie Brown  Follies  A Little Night Music  \
# 0                                 0        0                     0
#
#    La Cage aux Folles  Urinetown  Sunset Boulevard  Aladdin  Anastasia  \
# 0                   0          0                 0        0          0
#
#    The Secret Garden  Victor/Victoria  Assassins  Porgy and Bess  \
# 0                  0                0          0               0
#
#    Finding Neverland  Chitty Chitty Bang Bang  \
# 0                  0                        0
#
#    The 25th Annual Putnam County Spelling Bee  \
# 0                                           1
#
#    A Funny Thing Happened on the Way to the Forum  The Pirates of Penzance  \
# 0                                               0                        0
#
#    1776  Kiss Me, Kate  Damn Yankees  American Idiot  Chess  \
# 0     0              0             0               0      0
#
#    The Drowsy Chaperone  A Gentleman's Guide to Love and Murder  \
# 0                     0                                       0
#
#    The Fantasticks  Once  Jekyll and Hyde  Beautiful: the Carole King Musical  \
# 0                0     0                0                                   0
#
#    Brigadoon  On the Town  The Who's Tommy  Be More Chill  The Wiz  Fun Home  \
# 0          0            0                0              0        0         0
#
#    Catch Me If You Can  Sweet Charity  Mame  Seven Brides for Seven Brothers  \
# 0                    0              0     0                                0
#
#    Sister Act  She Loves Me  Candide  Starlight Express  Once Upon a Mattress  \
# 0           0             0        0                  0                     0
#
#    A Christmas Carol  Frozen  Natasha Pierre and the Great Comet of 1812  \
# 0                  0       0                                           0
#
#    Aida  The Light in the Piazza  Shrek the Musical  The Full Monty  \
# 0     0                        0                  0               0
#
#    The Best Little Whorehouse in Texas  pajama game  Big River  Bandstand  \
# 0                                    0            0          0          0
#
#    Rock of Ages  Bonnie & Clyde  Fame  Passion  The Band's Visit  \
# 0             1               0     0        0                 0
#
#    Kiss of the Spider Woman  Nine  Crazy for You  Memphis  Gigi  Beetlejuice  \
# 0                         0     0              0        0     0            0
#
#    Pal Joey  Parade  Wonderful Town  Grey Gardens  Flower Drum Song  Titanic  \
# 0         0       0               0             0                 0        0
#
#    Tarzan of the Apes  Side Show  A New Brain  Ain't Misbehavin'  \
# 0                   0          0            0                  0
#
#    Children of Eden  High School Musical on Stage!  Can-Can  City of Angels  \
# 0                 0                              0        0               0
#
#    Bells Are Ringing  Tuck Everlasting  \
# 0                  0                 0
#
#    Dr. Seuss' How the Grinch Stole Christmas!  Curtains  Fosse  Xanadu  \
# 0                                           0         0      0       0
#
#    Oh! Calcutta!  The Scarlet Pimpernel  Movin' Out  Dogfight  Applause  \
# 0              0                      0           0         0         0
#
#    Kismet  War Paint  Honk!  Blood Brothers  Suessical the Musical  Raisin  \
# 0       0          0      0               0                      0       0
#
#    Natasha, Pierre, and the Great Comet of 1812  Twisted  \
# 0                                             0        0
#
#    Dirty Rotten Scoundrels  Promises, Promises  Shenandoah  Carnival!  Coco  \
# 0                        0                   0           0          0     0
#
#    Fiorello!  Baby  Cyrano  Ballroom  The Magic Show  Dancin'  Do Re Mi  \
# 0          0     1       0         0               0        0         0
#
#    Redhead  Passing Strange  New girl in town  Grind  Big Deal
# 0        0                0                 0      0         0
