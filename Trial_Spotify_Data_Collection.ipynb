# %% [markdown]
# # Capstone: Musical Recommender

# %% [markdown]
# Kelly Slatery | US-DSI-10

# %% [markdown]
# Overview:
# - scrape musical names from Wikipedia
# - rank by popularity from spotify popularity rankings
# - get those movies' synopses from allmusicals.com

# %%
# !pip install spotipy

# %%
# Imports
import numpy as np
import pandas as np
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Credits: https://medium.com/@maxtingle/getting-started-with-spotifys-api-spotipy-197c3dc6353b
# Set up spotipy crednetials
cid = 'public_key'
secret = 'private_key'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
sp.search(q=album:gold%20artist:abba&type=album, limit=50, type='album')
# Out:
#   File "<ipython-input-21-6968df147d76>", line 1
#     sp.search(q=album:gold%20artist:abba&type=album, limit=50, type='album')
#                      ^
# SyntaxError: invalid syntax

# %%
hamiltons = sp.search(q='album:hamilton', type='album')

# %%
hamiltons['albums']['popularity']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-1bc011cc75e4> in <module>
# ----> 1 hamiltons['albums']['popularity']
#
# KeyError: 'popularity'

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,20):
    track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])

# %%
artist_name
# Out:
# ['Trevor Daniel',
#  'Juice WRLD',
#  'Juice WRLD',
#  'Billie Eilish',
#  'Post Malone',
#  'Joji',
#  'YNW Melly',
#  'Lil Baby',
#  'Meek Mill',
#  'Juice WRLD',
#  'Travis Scott',
#  'XXXTENTACION',
#  'A Boogie Wit da Hoodie',
#  'Post Malone',
#  'Arizona Zervas',
#  'Juice WRLD',
#  'Post Malone',
#  'Luke Combs',
#  'Juice WRLD',
#  'Morgan Wallen',
#  'Marshmello',
#  'XXXTENTACION',
#  'Lil Baby',
#  'Lil Mosey',
#  'Ski Mask The Slump God',
#  'XXXTENTACION',
#  'Kina',
#  'Halsey',
#  'XXXTENTACION',
#  'Panic! At The Disco',
#  '21 Savage',
#  'Drake',
#  'Morgan Wallen',
#  'Trippie Redd',
#  'Khalid',
#  'Dan + Shay',
#  'The Weeknd',
#  'Post Malone',
#  'Roddy Ricch',
#  'A Boogie Wit da Hoodie',
#  'Drake',
#  'Kodak Black',
#  'Juice WRLD',
#  'Dominic Fike',
#  'Cardi B',
#  'benny blanco',
#  'Sheck Wes',
#  'Lil Peep',
#  'Zedd',
#  'Alec Benjamin',
#  'Marshmello',
#  'XXXTENTACION',
#  'Lil Baby',
#  'Lil Mosey',
#  'Ski Mask The Slump God',
# ...

# %%
popularity
# Out:
# [97,
#  89,
#  84,
#  89,
#  86,
#  84,
#  83,
#  83,
#  84,
#  83,
#  86,
#  85,
#  83,
#  86,
#  84,
#  81,
#  85,
#  79,
#  81,
#  79,
#  87,
#  84,
#  80,
#  81,
#  80,
#  83,
#  86,
#  85,
#  82,
#  84,
#  80,
#  84,
#  77,
#  79,
#  79,
#  78,
#  83,
#  81,
#  78,
#  79,
#  80,
#  81,
#  78,
#  84,
#  82,
#  82,
#  80,
#  81,
#  82,
#  84,
#  87,
#  84,
#  80,
#  81,
#  80,
#  83,
#  86,
#  85,
#  82,
#  84,
#  80,
#  84,
#  77,
#  79,
#  79,
#  78,
#  83,
#  81,
#  78,
#  79,
#  80,
#  81,
#  78,
#  84,
#  82,
#  82,
#  80,
#  81,
#  82,
#  84,
#  77,
#  81,
#  82,
#  82,
#  83,
#  76,
#  78,
#  77,
#  80,
#  78,
#  85,
#  77,
#  86,
#  79,
#  79,
#  77,
#  76,
#  78,
#  76,
#  81,
#  80,
#  81,
#  78,
#  84,
#  82,
#  82,
#  80,
#  81,
#  82,
#  84,
#  77,
#  81,
#  82,
#  82,
#  83,
#  76,
#  78,
#  77,
#  80,
#  78,
#  85,
#  77,
#  86,
#  79,
#  79,
#  77,
#  76,
#  78,
#  76,
#  81,
#  79,
#  75,
#  77,
#  76,
#  77,
#  82,
#  85,
#  76,
#  82,
#  78,
#  77,
#  82,
# ...
