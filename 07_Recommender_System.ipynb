# %% [markdown]
# # Capstone: Musical Recommender

# %% [markdown]
# Kelly Slatery | US-DSI-10

# %%
# Imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import spacy
import en_core_web_lg
from textblob import TextBlob, Word

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv('./data/musical_sentiments.csv')
df.shape
# Out:
# (194, 7)

# %%
df.head()
# Out:
#                        name  \
# 0            Les Misérables
# 1  The Phantom of the Opera
# 2                  Hamilton
# 3           West Side Story
# 4                    Wicked
#
#                                             combined  \
# 0  Act I In 1815 France, prisoners work at hard l...
# 1  Prologue In 1911 Paris, the Paris Opéra hosts ...
# 2  The musical details Hamilton's life in two act...
# 3  Act 1 Two rival teenage gangs, the Jets (White...
# 4  Act I In the Land of Oz, the Ozians are rejoic...
#
#                                       clean_combined  \
# 0  France prisoner work hard labour work song yea...
# 1  prologue Paris Paris Opera host auction old th...
# 2  musical detail Hamilton life act historical ch...
# 3  rival teenage gang jet White Americans Sharks ...
# 4  Land Oz Ozians rejoice demise Elphaba Wicked W...
#
#                                              vectors  km_labels  db_labels  \
# 0  [-2.55308696e-03  1.25066981e-01 -3.78664001e-...          1          0
# 1  [ 4.53058779e-02  4.77313697e-02 -2.63329875e-...          3          0
# 2  [-6.79643005e-02  1.21977791e-01  1.33586982e-...          2          0
# 3  [-3.16287242e-02  6.83641210e-02 -4.60400395e-...          6          0
# 4  [ 1.18018501e-02  5.79135790e-02 -1.84583035e-...          3          0
#
#    sentiment
# 0   0.031586
# 1   0.001796
# 2   0.105111
# 3   0.107123
# 4   0.151201

# %% [markdown]
# # Process Data

# %%
nlp = en_core_web_lg.load()

# %%
df['docs'] = [nlp(summ) for summ in df['clean_combined']]

# %% [markdown]
# # Export Data

# %%
df[['name', 'docs', 'sentiment']].to_csv()
# Out:
# ',name,docs,sentiment\n0,Les Misérables,France prisoner work hard labour work song year prison steal bread sister starve son family rest try escape Jean Valjean prisoner release parole prison guard Javert law Valjean display yellow ticket leave identify ex convict parole convict Valjean shun go find regular work decent wage lodging Bishop Digne offer food shelter desperate embittered Valjean steal Bishop silver flee capture police turn Bishop lie tell police silver gift give Valjean pair silver candlestick addition Bishop tell Valjean use silver honest man buy Valjean soul God Valjean Arrested Valjean Forgiven ashamed humble Bishop kindness Valjean resolve redeem sin Valjean Soliloquy tear yellow ticket break parole give chance start new life free stigma criminal past year later Valjean assume new identity Monsieur Madeleine wealthy factory owner mayor Montreuil sur Mer Fantine single mother work factory try support daughter Cosette raise innkeeper wife Fantine labour city unbeknownst Valjean factory foreman lust Fantine reject advance take worker resent day coworker steal letter Cosette Fantine reveal worker Fantine child fight break foreman worker use incident pretence fire Fantine end Day Fantine reflect broken dream Cosette father abandon dream dream desperate money sell locket hair finally prostitute Lovely Ladies fight abusive customer Bamatabois Javert police inspector station Montreuil sur Mer arrive arrest Valjean pass scene pity Fantine realise work blame misfortune guilt stricken order Javert release take hospital Fantine Valjean rescue man Fauchelevent pin runaway cart Runaway Cart Javert recognise Valjean pursue fugitive year witness incident suspicious remember incredible strength Valjean display work camp turn man arrest trial break parole real Valjean realise case mistaken identity free forever willing innocent man prison place confess identity court Trial hospital delirious Fantine dream Cosette Valjean promise find Cosette protect come Fantine Death relieve Fantine succumb illness die Javert arrive Valjean custody Valjean ask Javert time fetch Cosette Javert refuse insist criminal Valjean change good struggle Valjean overpower Javert escape Montfermeil duplicitous innkeeper Thenardiers use Cosette servant treat cruelly extort money Fantine claim Cosette regularly seriously ill demand money feed clothe Cosette indulge daughter Eponine Cosette dream life mother force work treat lovingly Castle Cloud Thenardiers cheat customer steal possession set high price low quality service live life criminal depravity Master House Valjean meet Cosette errand drawing water offer Thenardiers payment adopt Bargain Thenardiers feign concern Cosette claim love daughter fragile health bargain Valjean pay franc end Valjean Cosette leave Paris Waltz year later Paris upheaval impending death General Lamarque man government show mercy poor mingle street student revolutionary Marius Pontmercy Enjolras contemplate effect Lamarque death poor desperate Paris Thenardiers lose inn run street gang consist thug Brujon Babet Claquesous Montparnasse Thenardier daughter Eponine grow fall love Marius oblivious affection streetwise young urchin Gavroche know happen slum look Thenardiers prepare con charitable visitor turn Valjean Cosette grow beautiful young woman gang bamboozle father Cosette run Marius pair fall love sight Thenardier suddenly recognise Valjean finish robbery Javert inspector station Paris come rescue Robbery Valjean Cosette escape later Thenardier tip Javert suspect Javert make vow star represent belief order universe suffering punishment sin find Valjean recapture star Marius persuade Eponine help find Cosette Eponine small cafe Enjolras exhort group idealistic student prepare revolution Marius interrupt atmosphere fantasise new find love amusement compatriot particularly wine love Grantaire ABC CafeRed Black Gavroche bring news General Lamarque death student realise use public dismay incite revolution time come hear sing Valj ...

# %% [markdown]
# # Build Recommender

# %%
# Define a function to take in user input and output a spaCy doc
def convert_to_doc(user_input):
    doc = nlp(user_input)
    return doc

# %%
# Define a function to take in user input and output its TextBlob sentiment
def get_sentiment(user_input):
    return TextBlob(user_input).sentiment.polarity

# %%
# Define a function to find each musical summary's sentiment and respective cosine similarity with the user input
def similarity_and_sentiments(user_input, df=df, summ_col='docs', sentiment_col='sentiment', name_col='name'):
    
    # Convert user input to a spaCy doc
    user_input_doc = convert_to_doc(user_input)
    
    # Calculate similarity with each musical and create dicitonary of similarities and sentiments
    similarity_dict = {}
    for i, summ in enumerate(df[summ_col]):
        sim = user_input_doc.similarity(summ)
        similarity_dict[sim] = [df[sentiment_col][i], df[name_col][i]]
    
    return similarity_dict

# %%
# Define a function to sort the list musical similarities and pull out top ten
def top_ten(similarity_dict):
    
    # Sort the musicals by similarity
    in_order = sorted(similarity_dict.items())
    
    # Consider only top 10 most similar musicals before including sentiment
    num_to_consider = 10
    
    # Pull out top 10 most similar musicals
    sentiment_list = []
    for i in range(num_to_consider):
        sentiment_list.append(in_order[-num_to_consider:][i][1])
    
    return sentiment_list

# %%
# Define a function to 
def get_recommendations(sentiment_list, user_input):
    
    # Calculate sentiment of user input
    user_sentiment = get_sentiment(user_input)
    
    # Pull out top 3 musicals with closest sentiment rating in either direction
    sentiment_differences = []
    for sentiment, musical in sentiment_list:
        diff = np.abs(user_sentiment - sentiment)
        sentiment_differences.append([diff, musical])
    
    # Extract musical names, in order
    top_three = sorted(sentiment_differences[:3])
    final_recommendations = []
    for sentiment, musical in top_three:
        final_recommendations.append(musical)
        
    return final_recommendations

# %%
# Define a function to take in user input and output 3 musical recommendations
def recommend(user_input):
    similarity_dict = similarity_and_sentiments(user_input)
    sentiment_list = top_ten(similarity_dict)
    final_recommendations = get_recommendations(sentiment_list, user_input)
    return final_recommendations

# %% [markdown]
# # Evaluate Recommender

# %% [markdown]
# #### Example 1

# %%
# Example prompt
prompt = """I feel kind of like trash. Today's been bad and my expectations haven't been met in a variety of ways. 
            I feel angered and honestly somewhat disrespected, and mostly in the mood to just relax and vent my
            emotions."""

# %%
# Get recommendations
recs_1 = recommend(prompt)
recs_1
# Out:
# ["The Band's Visit", 'American Idiot', 'Rock of Ages']

# %%
# Look at recommended musicals' clusters
df.loc[df['name'].isin(recs_1), ['name', 'km_labels', 'db_labels']]
# Out:
#                  name  km_labels  db_labels
# 101    American Idiot          4          0
# 135      Rock of Ages          5          0
# 139  The Band's Visit          5          0

# %% [markdown]
# #### Example 2

# %%
# Example prompt
prompt2 = '''I am feeling anxious but also excited. There is a lot of uncertainty in the world right now, 
with the coronavirus and the Trump presidency/election news. It's hard to feel settled. But we're
also doing fun and great things that are wonderful-- watching Kelly discover new skills and plan the next 
steps in her life, changing (drastically) the look of the home we've lived in for 17 years and planning 
exciting trips.
'''

# %%
# Get recommendations
recs_2 = recommend(prompt2)
recs_2
# Out:
# ['Chitty Chitty Bang Bang', 'Come from Away', 'Urinetown']

# %%
# Look at recommended musicals' clusters
df.loc[df['name'].isin(recs_2), ['name', 'km_labels', 'db_labels']]
# Out:
#                        name  km_labels  db_labels
# 76           Come from Away          5          0
# 85                Urinetown          5          0
# 94  Chitty Chitty Bang Bang          5          0

# %% [markdown]
# #### Example 3

# %%
# Example prompt
prompt3 = """I have no confidence in technology. I want to quit my job because of politics. 
My family thinks I am lazy at computers. I am tired of being disappointed in the country. I have no idea
what I will do in retirement. I am uncertain of the future and it makes me anxious.
"""

# %%
# Get recommendations
recs_3 = recommend(prompt3)
recs_3
# Out:
# ['Urinetown', 'Next to Normal', 'The 25th Annual Putnam County Spelling Bee']

# %%
# Look at recommended musicals' clusters
df.loc[df['name'].isin(recs_3), ['name', 'km_labels', 'db_labels']]
# Out:
#                                           name  km_labels  db_labels
# 42                              Next to Normal          4          0
# 85                                   Urinetown          5          0
# 95  The 25th Annual Putnam County Spelling Bee          5          0

# %% [markdown]
# As hoped, of the top three recommendations, at least 2 come from the same cluster from our earlier clustering models, which only clustered based on cosine similarity, without including any sentiment analysis. From my knowledge as a musical fan, these recommendations are extremely fitting, in terms of mood and topic.
